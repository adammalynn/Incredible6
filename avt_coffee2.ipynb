# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

raleighC_df = pd.read_csv("resources/yelp_data_coffee_raleigh-output_data.csv")
ashevilleC_df = pd.read_csv("resources/yelp_data_coffee_asheville-output_data.csv")

# %%
raleighC_df.head()
# Out:
#                   alias                                      categories  \
# 0  starbucks-raleigh-22  [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 1  starbucks-raleigh-21  [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 2  starbucks-raleigh-19  [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 3  starbucks-raleigh-17  [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 4  starbucks-raleigh-16  [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
#
#                                          coordinates   display_phone  \
# 0   {'latitude': 35.816105, 'longitude': -78.693763}  (919) 781-6211
# 1   {'latitude': 35.824885, 'longitude': -78.707222}  (919) 789-4422
# 2    {'latitude': 35.866613, 'longitude': -78.57499}  (919) 792-2227
# 3    {'latitude': 35.904845, 'longitude': -78.60199}  (919) 847-1363
# 4  {'latitude': 35.887828, 'longitude': -78.67873...  (919) 846-0633
#
#        distance                      id  \
# 0   3924.804270  PqPa5KcwNPqLl6kofX3AyA
# 1   5061.261095  ZpJkzU9Wx_Fg0K1MqjPEdQ
# 2   8389.750024  hTw6m26-NtAbgqDyyToKqg
# 3  10100.096911  i4fWrN_LeR-_upcvR-zVVQ
# 4   7604.410068  sblpZpiJf-WWeSvOgSztSg
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/a5w06_...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/Y6IHaK...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/XV-evm...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/zI5PzB...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/gQYkVA...      False
#
#                                             location       name         phone  \
# 0  {'address1': '3800 Lake Boone Trail', 'address...  Starbucks  1.919782e+10
# 1  {'address1': '3101-305 Edwards Mill Road', 'ad...  Starbucks  1.919789e+10
# 2  {'address1': '5959 Triangle Town Boulevard', '...  Starbucks  1.919792e+10
# 3  {'address1': '9630 Falls of the Neuse Road', '...  Starbucks  1.919847e+10
# 4  {'address1': '7498 Creedmor Road', 'address2':...  Starbucks  1.919846e+10
#
#   price  rating  review_count transactions  \
# 0    $$     3.0            38           []
# 1    $$     4.0            16           []
# 2    $$     4.0            14           []
# 3    $$     3.5            27           []
# 4    $$     3.5            28           []
#
#                                                  url
# 0  https://www.yelp.com/biz/starbucks-raleigh-22?...
# 1  https://www.yelp.com/biz/starbucks-raleigh-21?...
# 2  https://www.yelp.com/biz/starbucks-raleigh-19?...
# 3  https://www.yelp.com/biz/starbucks-raleigh-17?...
# 4  https://www.yelp.com/biz/starbucks-raleigh-16?...

# %%
raleighC_df.tail()
# Out:
#                    alias                                         categories  \
# 84  starbucks-raleigh-32     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 85     starbucks-cary-14     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 86      jets-coffee-cary  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 87    mcdonalds-garner-5  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...
# 88   circle-k-raleigh-12  [{'alias': 'servicestations', 'title': 'Gas St...
#
#                                           coordinates   display_phone  \
# 84     {'latitude': 35.86614, 'longitude': -78.56797}  (919) 790-1024
# 85   {'latitude': 35.775164, 'longitude': -78.764947}  (919) 481-4251
# 86     {'latitude': 35.77377, 'longitude': -78.76025}  (919) 481-0311
# 87  {'latitude': 35.7247354, 'longitude': -78.6495...  (919) 772-9496
# 88     {'latitude': 35.86067, 'longitude': -78.60021}  (919) 875-0618
#
#         distance                      id  \
# 84   8886.383528  HFRQ72qu3cM-oGtvbiSktA
# 85  11572.182208  -EO9Ac0yye3rfFCl8yqfUA
# 86  11083.235788  H3rjD4FulsMg0B9lXFz0Hw
# 87  10950.243337  XQH2soIPKGbjZxgG-zZ0wQ
# 88   6199.584650  eqsPJO4amFtgh7KUVWtUZA
#
#                                             image_url  is_closed  \
# 84  https://s3-media2.fl.yelpcdn.com/bphoto/A8Z6ap...      False
# 85  https://s3-media2.fl.yelpcdn.com/bphoto/8rm60I...      False
# 86  https://s3-media2.fl.yelpcdn.com/bphoto/IPilz6...      False
# 87  https://s3-media3.fl.yelpcdn.com/bphoto/VsWk3x...      False
# 88  https://s3-media1.fl.yelpcdn.com/bphoto/iaXOlR...      False
#
#                                              location         name  \
# 84  {'address1': '7900 Old Wake Forest Rd', 'addre...    Starbucks
# 85  {'address1': '885 Walnut St', 'address2': None...    Starbucks
# 86  {'address1': '1105 Walnut St', 'address2': '',...  Jets Coffee
# 87  {'address1': '1567 Hwy 70 W', 'address2': None...   McDonald's
# 88  {'address1': '2400 Spring Forest Rd', 'address...     Circle K
#
#            phone price  rating  review_count transactions  \
# 84  1.919790e+10    $$     1.0             2           []
# 85  1.919481e+10   NaN     5.0             1           []
# 86  1.919481e+10   NaN     3.0             5           []
# 87  1.919773e+10     $     1.5             7           []
# 88  1.919875e+10   $$$     1.0             1           []
#
#                                                   url
# 84  https://www.yelp.com/biz/starbucks-raleigh-32?...
# 85  https://www.yelp.com/biz/starbucks-cary-14?adj...
# 86  https://www.yelp.com/biz/jets-coffee-cary?adju...
# 87  https://www.yelp.com/biz/mcdonalds-garner-5?ad...
# 88  https://www.yelp.com/biz/circle-k-raleigh-12?a...

# %%
raleighC_df.head()
# Out:
#                   alias                                      categories  \
# 0  starbucks-raleigh-22  [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 1  starbucks-raleigh-21  [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 2  starbucks-raleigh-19  [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 3  starbucks-raleigh-17  [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 4  starbucks-raleigh-16  [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
#
#                                          coordinates   display_phone  \
# 0   {'latitude': 35.816105, 'longitude': -78.693763}  (919) 781-6211
# 1   {'latitude': 35.824885, 'longitude': -78.707222}  (919) 789-4422
# 2    {'latitude': 35.866613, 'longitude': -78.57499}  (919) 792-2227
# 3    {'latitude': 35.904845, 'longitude': -78.60199}  (919) 847-1363
# 4  {'latitude': 35.887828, 'longitude': -78.67873...  (919) 846-0633
#
#        distance                      id  \
# 0   3924.804270  PqPa5KcwNPqLl6kofX3AyA
# 1   5061.261095  ZpJkzU9Wx_Fg0K1MqjPEdQ
# 2   8389.750024  hTw6m26-NtAbgqDyyToKqg
# 3  10100.096911  i4fWrN_LeR-_upcvR-zVVQ
# 4   7604.410068  sblpZpiJf-WWeSvOgSztSg
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/a5w06_...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/Y6IHaK...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/XV-evm...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/zI5PzB...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/gQYkVA...      False
#
#                                             location       name         phone  \
# 0  {'address1': '3800 Lake Boone Trail', 'address...  Starbucks  1.919782e+10
# 1  {'address1': '3101-305 Edwards Mill Road', 'ad...  Starbucks  1.919789e+10
# 2  {'address1': '5959 Triangle Town Boulevard', '...  Starbucks  1.919792e+10
# 3  {'address1': '9630 Falls of the Neuse Road', '...  Starbucks  1.919847e+10
# 4  {'address1': '7498 Creedmor Road', 'address2':...  Starbucks  1.919846e+10
#
#   price  rating  review_count transactions  \
# 0    $$     3.0            38           []
# 1    $$     4.0            16           []
# 2    $$     4.0            14           []
# 3    $$     3.5            27           []
# 4    $$     3.5            28           []
#
#                                                  url
# 0  https://www.yelp.com/biz/starbucks-raleigh-22?...
# 1  https://www.yelp.com/biz/starbucks-raleigh-21?...
# 2  https://www.yelp.com/biz/starbucks-raleigh-19?...
# 3  https://www.yelp.com/biz/starbucks-raleigh-17?...
# 4  https://www.yelp.com/biz/starbucks-raleigh-16?...

# %%
ashevilleC_df.tail()
# Out:
#                     alias                                         categories  \
# 38        mcdonalds-arden  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...
# 39   mcdonalds-fletcher-3  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 40  starbucks-weaverville     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 41      starbucks-arden-4     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 42        starbucks-arden     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
#
#                                           coordinates   display_phone  \
# 38     {'latitude': 35.48244, 'longitude': -82.55379}  (828) 651-4467
# 39    {'latitude': 35.443816, 'longitude': -82.53369}  (828) 654-0031
# 40   {'latitude': 35.702824, 'longitude': -82.567121}  (828) 645-2902
# 41   {'latitude': 35.479698, 'longitude': -82.549492}  (828) 681-5173
# 42  {'latitude': 35.44890348, 'longitude': -82.536...  (828) 681-0341
#
#         distance                      id  \
# 38  11167.151763  1adPhlhKhFjdkdWWai71vw
# 39  15610.334456  L2G0GsG03iU4RTWryNOYZQ
# 40  13359.396758  tcyku0W4Cl2yekVLQgWTZA
# 41  11503.827880  QwA2IZnLUCYfVUh211CEGw
# 42  15017.096717  aHuSlLaPJA2Ip1nibBmC-Q
#
#                                             image_url  is_closed  \
# 38  https://s3-media3.fl.yelpcdn.com/bphoto/P0oplb...      False
# 39  https://s3-media3.fl.yelpcdn.com/bphoto/_GugyK...      False
# 40  https://s3-media1.fl.yelpcdn.com/bphoto/iZLOTc...      False
# 41  https://s3-media4.fl.yelpcdn.com/bphoto/Pm7x6d...      False
# 42  https://s3-media3.fl.yelpcdn.com/bphoto/0qNzGW...      False
#
#                                              location        name  \
# 38  {'address1': '382 Long Shoals Rd', 'address2':...  McDonald's
# 39  {'address1': '525 Airport Rd', 'address2': Non...  McDonald's
# 40  {'address1': '140 Weaver Blvd', 'address2': ''...   Starbucks
# 41  {'address1': '301 Long Shoals Rd', 'address2':...   Starbucks
# 42  {'address1': '15 Mckenna Rd', 'address2': '', ...   Starbucks
#
#            phone price  rating  review_count transactions  \
# 38  1.828651e+10     $     2.0            10           []
# 39  1.828654e+10     $     2.0            16           []
# 40  1.828645e+10    $$     3.0             3           []
# 41  1.828682e+10    $$     2.0             4           []
# 42  1.828681e+10    $$     2.5             3           []
#
#                                                   url
# 38  https://www.yelp.com/biz/mcdonalds-arden?adjus...
# 39  https://www.yelp.com/biz/mcdonalds-fletcher-3?...
# 40  https://www.yelp.com/biz/starbucks-weaverville...
# 41  https://www.yelp.com/biz/starbucks-arden-4?adj...
# 42  https://www.yelp.com/biz/starbucks-arden?adjus...

# %%
#Data analysis - to make sure no duplicates exist
unique_raleigh_alias = len(raleighC_df['alias'].unique())
unique_raleigh_alias
# Out:
# 89

# %%
#Create dataframe with only the columns you need (alias, coordinates, name, price, rating, review_count)
new_raleigh_df = raleighC_df[['alias', 'name','rating', 'price', 'review_count', 'coordinates']]
new_raleigh_df.head()
# Out:
#                   alias       name  rating price  review_count  \
# 0  starbucks-raleigh-22  Starbucks     3.0    $$            38
# 1  starbucks-raleigh-21  Starbucks     4.0    $$            16
# 2  starbucks-raleigh-19  Starbucks     4.0    $$            14
# 3  starbucks-raleigh-17  Starbucks     3.5    $$            27
# 4  starbucks-raleigh-16  Starbucks     3.5    $$            28
#
#                                          coordinates
# 0   {'latitude': 35.816105, 'longitude': -78.693763}
# 1   {'latitude': 35.824885, 'longitude': -78.707222}
# 2    {'latitude': 35.866613, 'longitude': -78.57499}
# 3    {'latitude': 35.904845, 'longitude': -78.60199}
# 4  {'latitude': 35.887828, 'longitude': -78.67873...

# %%
#Sort dataframe by rating (descending = top 5)
top_raleighC = new_raleigh_df.sort_values(['rating'], ascending=False)
top_raleighC
# Out:
#                                       alias                           name  \
# 85                        starbucks-cary-14                      Starbucks
# 10                hillsborough-mart-raleigh              Hillsborough Mart
# 73  western-dragon-teas-and-tisanes-raleigh  Western Dragon Teas & Tisanes
# 64                 holy-moly-cannoli-durham              Holy Moly Cannoli
# 23                  kale-me-crazy-raleigh-2                  Kale Me Crazy
# 13                      mcdonalds-raleigh-6                     McDonald's
# 35                     starbucks-raleigh-43                      Starbucks
# 41                 port-city-java-raleigh-6                 Port City Java
# 28                          crema-raleigh-2                          Crema
# 66                    hill-of-beans-raleigh                  Hill Of Beans
# 20                     cup-o-jane-raleigh-2                     Cup O Jane
# 68                       circle-k-raleigh-4                       Circle K
# 69               the-campus-grind-raleigh-2               The Campus Grind
# 19                      pattis-cafe-raleigh                   Patti's Cafe
# 81                         starbucks-cary-5                      Starbucks
# 8                         sheetz-raleigh-19                         Sheetz
# 47                        starbucks-cary-10                      Starbucks
# 1                      starbucks-raleigh-21                      Starbucks
# 2                      starbucks-raleigh-19                      Starbucks
# 53                         starbucks-cary-9                      Starbucks
# 26               pinnacle-nutrition-raleigh             Pinnacle Nutrition
# 43                         java-jive-cary-2                      Java Jive
# 61              k-and-s-cafeteria-raleigh-7                  K&S Cafeteria
# 58                         circle-k-raleigh                       Circle K
# 44                     starbucks-raleigh-30                      Starbucks
# 18                      mcdonalds-raleigh-7                     McDonald's
# 72  morgan-street-java-and-creperie-raleigh  Morgan Street Java & Creperie
# 9         caretta-coffee-and-cafe-raleigh-2          Caretta Coffee & Cafe
# 6                       the-outpost-raleigh                    The Outpost
# 4                      starbucks-raleigh-16                      Starbucks
# ..                                      ...                            ...
# 36            gloria-jeans-coffee-raleigh-2           Gloria Jean's Coffee
# 37                     mcdonalds-raleigh-34                     McDonald's
# 38                     mcdonalds-raleigh-43                     McDonald's
# 74                         mcdonalds-cary-5                     McDonald's
# 76                 dunkin-donuts-raleigh-16                 Dunkin' Donuts
# 39                     mcdonalds-raleigh-24                     McDonald's
# 24                     starbucks-raleigh-41                      Starbucks
# 49                      mcdonalds-raleigh-5                     McDonald's
# 57           paradise-hookah-lounge-raleigh         Paradise Hookah Lounge
# 31                     mcdonalds-raleigh-15                     McDonald's
# 48                  dunkin-donuts-raleigh-7                 Dunkin' Donuts
# 32                     mcdonalds-raleigh-19                     McDonald's
# 78                        mcdonalds-raleigh                     McDonald's
# 87                       mcdonalds-garner-5                     McDonald's
# 45                      mcdonalds-raleigh-8                     McDonald's
# 46                     mcdonalds-raleigh-27                     McDonald's
# 83                         mcdonalds-cary-6                     McDonald's
# 80                 port-city-java-raleigh-9                 Port City Java
# 79                           mcdonalds-cary                     McDonald's
# 40                    dunkin-donuts-raleigh                 Dunkin' Donuts
# 59                     mcdonalds-raleigh-44                     McDonald's
# 75                     mcdonalds-raleigh-45                     McDonald's
# 51                     mcdonalds-raleigh-29                     McDonald's
# 52                      mcdonalds-raleigh-9                     McDonald's
# 55                  dunkin-donuts-raleigh-8                 Dunkin' Donuts
# 56                     mcdonalds-raleigh-39                     McDonald's
# 82                     mcdonalds-raleigh-47                     McDonald's
# 84                     starbucks-raleigh-32                      Starbucks
# 71                      mcdonalds-raleigh-3                     McDonald's
# 88                      circle-k-raleigh-12                       Circle K
#
#     rating price  review_count  \
# 85     5.0   NaN             1
# 10     5.0     $             5
# 73     5.0   NaN             2
# 64     5.0   NaN             7
# 23     4.5   NaN             3
# 13     4.5     $             6
# 35     4.5     $             3
# 41     4.5     $             2
# 28     4.5   NaN             4
# 66     4.0   NaN             1
# 20     4.0     $             6
# 68     4.0   NaN             1
# 69     4.0     $             1
# 19     4.0     $             7
# 81     4.0   NaN             4
# 8      4.0   NaN            11
# 47     4.0     $            20
# 1      4.0    $$            16
# 2      4.0    $$            14
# 53     3.5    $$            15
# 26     3.5    $$             6
# 43     3.5     $            60
# 61     3.5     $             3
# 58     3.5    $$             2
# 44     3.5   NaN             3
# 18     3.5     $            10
# 72     3.5   NaN             2
# 9      3.5   NaN            18
# 6      3.5     $            17
# 4      3.5    $$            28
# ..     ...   ...           ...
# 36     2.5     $            10
# 37     2.5     $            10
# 38     2.5     $            16
# 74     2.0     $            29
# 76     2.0     $             9
# 39     2.0     $            24
# 24     2.0    $$            37
# 49     2.0     $            13
# 57     2.0    $$            10
# 31     2.0     $            22
# 48     2.0     $            16
# 32     2.0     $            30
# 78     1.5     $             7
# 87     1.5     $             7
# 45     1.5     $            34
# 46     1.5     $            25
# 83     1.5     $            26
# 80     1.5     $             2
# 79     1.5     $            33
# 40     1.5     $            30
# 59     1.5     $            15
# 75     1.5   NaN             3
# 51     1.5     $            13
# 52     1.5     $            13
# 55     1.5   NaN            12
# 56     1.5     $            12
# 82     1.0   NaN             1
# 84     1.0    $$             2
# 71     1.0   NaN            10
# 88     1.0   $$$             1
#
#                                           coordinates
# 85   {'latitude': 35.775164, 'longitude': -78.764947}
# 10   {'latitude': 35.7831199, 'longitude': -78.65621}
# 73     {'latitude': 35.77945, 'longitude': -78.64568}
# 64     {'latitude': 35.93373, 'longitude': -79.01584}
# 23  {'latitude': 35.7910333, 'longitude': -78.6609...
# 13  {'latitude': 35.7237350457159, 'longitude': -7...
# 35  {'latitude': 35.78347336, 'longitude': -78.670...
# 41     {'latitude': 35.79738, 'longitude': -78.70438}
# 28      {'latitude': 35.7744, 'longitude': -78.63936}
# 66  {'latitude': 35.7875118, 'longitude': -78.6696...
# 20  {'latitude': 35.7940979003906, 'longitude': -7...
# 68     {'latitude': 35.79847, 'longitude': -78.55692}
# 69   {'latitude': 35.86684, 'longitude': -78.5417499}
# 19    {'latitude': 35.89582, 'longitude': -78.659103}
# 81    {'latitude': 35.74687, 'longitude': -78.743381}
# 8    {'latitude': 35.862906, 'longitude': -78.599158}
# 47     {'latitude': 35.74615, 'longitude': -78.74189}
# 1    {'latitude': 35.824885, 'longitude': -78.707222}
# 2     {'latitude': 35.866613, 'longitude': -78.57499}
# 53   {'latitude': 35.771534, 'longitude': -78.762499}
# 26  {'latitude': 35.7439383895825, 'longitude': -7...
# 43      {'latitude': 35.72829, 'longitude': -78.7766}
# 61  {'latitude': 35.7678038, 'longitude': -78.7407...
# 58     {'latitude': 35.84836, 'longitude': -78.60065}
# 44   {'latitude': 35.837276, 'longitude': -78.642334}
# 18  {'latitude': 35.7991136276413, 'longitude': -7...
# 72   {'latitude': 35.77945, 'longitude': -78.6456805}
# 9   {'latitude': 35.9069964943874, 'longitude': -7...
# 6      {'latitude': 35.77787, 'longitude': -78.63456}
# 4   {'latitude': 35.887828, 'longitude': -78.67873...
# ..                                                ...
# 36    {'latitude': 35.840273, 'longitude': -78.68044}
# 37  {'latitude': 35.8387921407526, 'longitude': -7...
# 38  {'latitude': 35.9092435498945, 'longitude': -7...
# 74  {'latitude': 35.8297788580362, 'longitude': -7...
# 76  {'latitude': 35.8991828840439, 'longitude': -7...
# 39    {'latitude': 35.90633, 'longitude': -78.601383}
# 24   {'latitude': 35.773846, 'longitude': -78.639637}
# 49  {'latitude': 35.9002554552376, 'longitude': -7...
# 57  {'latitude': 35.8307228088379, 'longitude': -7...
# 31  {'latitude': 35.8191246456017, 'longitude': -7...
# 48    {'latitude': 35.887576, 'longitude': -78.74405}
# 32  {'latitude': 35.863362088857, 'longitude': -78...
# 78  {'latitude': 35.8205101, 'longitude': -78.5912...
# 87  {'latitude': 35.7247354, 'longitude': -78.6495...
# 45  {'latitude': 35.7852416, 'longitude': -78.6879...
# 46  {'latitude': 35.7900417, 'longitude': -78.7407...
# 83  {'latitude': 35.7764412369757, 'longitude': -7...
# 80  {'latitude': 35.7885869, 'longitude': -78.6733...
# 79  {'latitude': 35.7590502533454, 'longitude': -7...
# 40  {'latitude': 35.7357958664346, 'longitude': -7...
# 59  {'latitude': 35.7724070648646, 'longitude': -7...
# 75  {'latitude': 35.8386157, 'longitude': -78.6751...
# 51  {'latitude': 35.7905898785025, 'longitude': -7...
# 52  {'latitude': 35.8799164272446, 'longitude': -7...
# 55  {'latitude': 35.8417176029815, 'longitude': -7...
# 56  {'latitude': 35.8701926475536, 'longitude': -7...
# 82     {'latitude': 35.800831, 'longitude': -78.5601}
# 84     {'latitude': 35.86614, 'longitude': -78.56797}
# 71  {'latitude': 35.8554331326843, 'longitude': -7...
# 88     {'latitude': 35.86067, 'longitude': -78.60021}
#
# [89 rows x 6 columns]

# %%
#Top ratings by name
top_raleighC_name = top_raleighC.groupby(['rating', 'name'])
top_raleighC_name

# %%
#Sort dataframe by rating (ascending = botton 5)
bottom_raleighC = new_raleigh_df.sort_values(['rating'], ascending=True)
bottom_raleighC
# Out:
#                                       alias                           name  \
# 88                      circle-k-raleigh-12                       Circle K
# 84                     starbucks-raleigh-32                      Starbucks
# 82                     mcdonalds-raleigh-47                     McDonald's
# 71                      mcdonalds-raleigh-3                     McDonald's
# 45                      mcdonalds-raleigh-8                     McDonald's
# 87                       mcdonalds-garner-5                     McDonald's
# 51                     mcdonalds-raleigh-29                     McDonald's
# 40                    dunkin-donuts-raleigh                 Dunkin' Donuts
# 52                      mcdonalds-raleigh-9                     McDonald's
# 55                  dunkin-donuts-raleigh-8                 Dunkin' Donuts
# 56                     mcdonalds-raleigh-39                     McDonald's
# 46                     mcdonalds-raleigh-27                     McDonald's
# 59                     mcdonalds-raleigh-44                     McDonald's
# 83                         mcdonalds-cary-6                     McDonald's
# 80                 port-city-java-raleigh-9                 Port City Java
# 79                           mcdonalds-cary                     McDonald's
# 78                        mcdonalds-raleigh                     McDonald's
# 75                     mcdonalds-raleigh-45                     McDonald's
# 74                         mcdonalds-cary-5                     McDonald's
# 49                      mcdonalds-raleigh-5                     McDonald's
# 39                     mcdonalds-raleigh-24                     McDonald's
# 32                     mcdonalds-raleigh-19                     McDonald's
# 31                     mcdonalds-raleigh-15                     McDonald's
# 76                 dunkin-donuts-raleigh-16                 Dunkin' Donuts
# 57           paradise-hookah-lounge-raleigh         Paradise Hookah Lounge
# 48                  dunkin-donuts-raleigh-7                 Dunkin' Donuts
# 24                     starbucks-raleigh-41                      Starbucks
# 70                port-city-java-raleigh-10                 Port City Java
# 15                     mcdonalds-raleigh-17                     McDonald's
# 16                     starbucks-raleigh-38                      Starbucks
# ..                                      ...                            ...
# 3                      starbucks-raleigh-17                      Starbucks
# 4                      starbucks-raleigh-16                      Starbucks
# 6                       the-outpost-raleigh                    The Outpost
# 9         caretta-coffee-and-cafe-raleigh-2          Caretta Coffee & Cafe
# 72  morgan-street-java-and-creperie-raleigh  Morgan Street Java & Creperie
# 18                      mcdonalds-raleigh-7                     McDonald's
# 44                     starbucks-raleigh-30                      Starbucks
# 53                         starbucks-cary-9                      Starbucks
# 26               pinnacle-nutrition-raleigh             Pinnacle Nutrition
# 61              k-and-s-cafeteria-raleigh-7                  K&S Cafeteria
# 58                         circle-k-raleigh                       Circle K
# 66                    hill-of-beans-raleigh                  Hill Of Beans
# 1                      starbucks-raleigh-21                      Starbucks
# 2                      starbucks-raleigh-19                      Starbucks
# 81                         starbucks-cary-5                      Starbucks
# 8                         sheetz-raleigh-19                         Sheetz
# 20                     cup-o-jane-raleigh-2                     Cup O Jane
# 69               the-campus-grind-raleigh-2               The Campus Grind
# 47                        starbucks-cary-10                      Starbucks
# 19                      pattis-cafe-raleigh                   Patti's Cafe
# 68                       circle-k-raleigh-4                       Circle K
# 13                      mcdonalds-raleigh-6                     McDonald's
# 28                          crema-raleigh-2                          Crema
# 35                     starbucks-raleigh-43                      Starbucks
# 41                 port-city-java-raleigh-6                 Port City Java
# 23                  kale-me-crazy-raleigh-2                  Kale Me Crazy
# 10                hillsborough-mart-raleigh              Hillsborough Mart
# 73  western-dragon-teas-and-tisanes-raleigh  Western Dragon Teas & Tisanes
# 64                 holy-moly-cannoli-durham              Holy Moly Cannoli
# 85                        starbucks-cary-14                      Starbucks
#
#     rating price  review_count  \
# 88     1.0   $$$             1
# 84     1.0    $$             2
# 82     1.0   NaN             1
# 71     1.0   NaN            10
# 45     1.5     $            34
# 87     1.5     $             7
# 51     1.5     $            13
# 40     1.5     $            30
# 52     1.5     $            13
# 55     1.5   NaN            12
# 56     1.5     $            12
# 46     1.5     $            25
# 59     1.5     $            15
# 83     1.5     $            26
# 80     1.5     $             2
# 79     1.5     $            33
# 78     1.5     $             7
# 75     1.5   NaN             3
# 74     2.0     $            29
# 49     2.0     $            13
# 39     2.0     $            24
# 32     2.0     $            30
# 31     2.0     $            22
# 76     2.0     $             9
# 57     2.0    $$            10
# 48     2.0     $            16
# 24     2.0    $$            37
# 70     2.5   NaN             2
# 15     2.5     $            26
# 16     2.5    $$            31
# ..     ...   ...           ...
# 3      3.5    $$            27
# 4      3.5    $$            28
# 6      3.5     $            17
# 9      3.5   NaN            18
# 72     3.5   NaN             2
# 18     3.5     $            10
# 44     3.5   NaN             3
# 53     3.5    $$            15
# 26     3.5    $$             6
# 61     3.5     $             3
# 58     3.5    $$             2
# 66     4.0   NaN             1
# 1      4.0    $$            16
# 2      4.0    $$            14
# 81     4.0   NaN             4
# 8      4.0   NaN            11
# 20     4.0     $             6
# 69     4.0     $             1
# 47     4.0     $            20
# 19     4.0     $             7
# 68     4.0   NaN             1
# 13     4.5     $             6
# 28     4.5   NaN             4
# 35     4.5     $             3
# 41     4.5     $             2
# 23     4.5   NaN             3
# 10     5.0     $             5
# 73     5.0   NaN             2
# 64     5.0   NaN             7
# 85     5.0   NaN             1
#
#                                           coordinates
# 88     {'latitude': 35.86067, 'longitude': -78.60021}
# 84     {'latitude': 35.86614, 'longitude': -78.56797}
# 82     {'latitude': 35.800831, 'longitude': -78.5601}
# 71  {'latitude': 35.8554331326843, 'longitude': -7...
# 45  {'latitude': 35.7852416, 'longitude': -78.6879...
# 87  {'latitude': 35.7247354, 'longitude': -78.6495...
# 51  {'latitude': 35.7905898785025, 'longitude': -7...
# 40  {'latitude': 35.7357958664346, 'longitude': -7...
# 52  {'latitude': 35.8799164272446, 'longitude': -7...
# 55  {'latitude': 35.8417176029815, 'longitude': -7...
# 56  {'latitude': 35.8701926475536, 'longitude': -7...
# 46  {'latitude': 35.7900417, 'longitude': -78.7407...
# 59  {'latitude': 35.7724070648646, 'longitude': -7...
# 83  {'latitude': 35.7764412369757, 'longitude': -7...
# 80  {'latitude': 35.7885869, 'longitude': -78.6733...
# 79  {'latitude': 35.7590502533454, 'longitude': -7...
# 78  {'latitude': 35.8205101, 'longitude': -78.5912...
# 75  {'latitude': 35.8386157, 'longitude': -78.6751...
# 74  {'latitude': 35.8297788580362, 'longitude': -7...
# 49  {'latitude': 35.9002554552376, 'longitude': -7...
# 39    {'latitude': 35.90633, 'longitude': -78.601383}
# 32  {'latitude': 35.863362088857, 'longitude': -78...
# 31  {'latitude': 35.8191246456017, 'longitude': -7...
# 76  {'latitude': 35.8991828840439, 'longitude': -7...
# 57  {'latitude': 35.8307228088379, 'longitude': -7...
# 48    {'latitude': 35.887576, 'longitude': -78.74405}
# 24   {'latitude': 35.773846, 'longitude': -78.639637}
# 70  {'latitude': 35.7859827, 'longitude': -78.6671...
# 15   {'latitude': 35.836028, 'longitude': -78.675723}
# 16   {'latitude': 35.855675, 'longitude': -78.580519}
# ..                                                ...
# 3     {'latitude': 35.904845, 'longitude': -78.60199}
# 4   {'latitude': 35.887828, 'longitude': -78.67873...
# 6      {'latitude': 35.77787, 'longitude': -78.63456}
# 9   {'latitude': 35.9069964943874, 'longitude': -7...
# 72   {'latitude': 35.77945, 'longitude': -78.6456805}
# 18  {'latitude': 35.7991136276413, 'longitude': -7...
# 44   {'latitude': 35.837276, 'longitude': -78.642334}
# 53   {'latitude': 35.771534, 'longitude': -78.762499}
# 26  {'latitude': 35.7439383895825, 'longitude': -7...
# 61  {'latitude': 35.7678038, 'longitude': -78.7407...
# 58     {'latitude': 35.84836, 'longitude': -78.60065}
# 66  {'latitude': 35.7875118, 'longitude': -78.6696...
# 1    {'latitude': 35.824885, 'longitude': -78.707222}
# 2     {'latitude': 35.866613, 'longitude': -78.57499}
# 81    {'latitude': 35.74687, 'longitude': -78.743381}
# 8    {'latitude': 35.862906, 'longitude': -78.599158}
# 20  {'latitude': 35.7940979003906, 'longitude': -7...
# 69   {'latitude': 35.86684, 'longitude': -78.5417499}
# 47     {'latitude': 35.74615, 'longitude': -78.74189}
# 19    {'latitude': 35.89582, 'longitude': -78.659103}
# 68     {'latitude': 35.79847, 'longitude': -78.55692}
# 13  {'latitude': 35.7237350457159, 'longitude': -7...
# 28      {'latitude': 35.7744, 'longitude': -78.63936}
# 35  {'latitude': 35.78347336, 'longitude': -78.670...
# 41     {'latitude': 35.79738, 'longitude': -78.70438}
# 23  {'latitude': 35.7910333, 'longitude': -78.6609...
# 10   {'latitude': 35.7831199, 'longitude': -78.65621}
# 73     {'latitude': 35.77945, 'longitude': -78.64568}
# 64     {'latitude': 35.93373, 'longitude': -79.01584}
# 85   {'latitude': 35.775164, 'longitude': -78.764947}
#
# [89 rows x 6 columns]

# %%
#Bottom ratings by name.
bottom_raleighC_name = bottom_raleighC.groupby(['rating', 'name'])
bottom_raleighC
# Out:
#                                       alias                           name  \
# 88                      circle-k-raleigh-12                       Circle K
# 84                     starbucks-raleigh-32                      Starbucks
# 82                     mcdonalds-raleigh-47                     McDonald's
# 71                      mcdonalds-raleigh-3                     McDonald's
# 45                      mcdonalds-raleigh-8                     McDonald's
# 87                       mcdonalds-garner-5                     McDonald's
# 51                     mcdonalds-raleigh-29                     McDonald's
# 40                    dunkin-donuts-raleigh                 Dunkin' Donuts
# 52                      mcdonalds-raleigh-9                     McDonald's
# 55                  dunkin-donuts-raleigh-8                 Dunkin' Donuts
# 56                     mcdonalds-raleigh-39                     McDonald's
# 46                     mcdonalds-raleigh-27                     McDonald's
# 59                     mcdonalds-raleigh-44                     McDonald's
# 83                         mcdonalds-cary-6                     McDonald's
# 80                 port-city-java-raleigh-9                 Port City Java
# 79                           mcdonalds-cary                     McDonald's
# 78                        mcdonalds-raleigh                     McDonald's
# 75                     mcdonalds-raleigh-45                     McDonald's
# 74                         mcdonalds-cary-5                     McDonald's
# 49                      mcdonalds-raleigh-5                     McDonald's
# 39                     mcdonalds-raleigh-24                     McDonald's
# 32                     mcdonalds-raleigh-19                     McDonald's
# 31                     mcdonalds-raleigh-15                     McDonald's
# 76                 dunkin-donuts-raleigh-16                 Dunkin' Donuts
# 57           paradise-hookah-lounge-raleigh         Paradise Hookah Lounge
# 48                  dunkin-donuts-raleigh-7                 Dunkin' Donuts
# 24                     starbucks-raleigh-41                      Starbucks
# 70                port-city-java-raleigh-10                 Port City Java
# 15                     mcdonalds-raleigh-17                     McDonald's
# 16                     starbucks-raleigh-38                      Starbucks
# ..                                      ...                            ...
# 3                      starbucks-raleigh-17                      Starbucks
# 4                      starbucks-raleigh-16                      Starbucks
# 6                       the-outpost-raleigh                    The Outpost
# 9         caretta-coffee-and-cafe-raleigh-2          Caretta Coffee & Cafe
# 72  morgan-street-java-and-creperie-raleigh  Morgan Street Java & Creperie
# 18                      mcdonalds-raleigh-7                     McDonald's
# 44                     starbucks-raleigh-30                      Starbucks
# 53                         starbucks-cary-9                      Starbucks
# 26               pinnacle-nutrition-raleigh             Pinnacle Nutrition
# 61              k-and-s-cafeteria-raleigh-7                  K&S Cafeteria
# 58                         circle-k-raleigh                       Circle K
# 66                    hill-of-beans-raleigh                  Hill Of Beans
# 1                      starbucks-raleigh-21                      Starbucks
# 2                      starbucks-raleigh-19                      Starbucks
# 81                         starbucks-cary-5                      Starbucks
# 8                         sheetz-raleigh-19                         Sheetz
# 20                     cup-o-jane-raleigh-2                     Cup O Jane
# 69               the-campus-grind-raleigh-2               The Campus Grind
# 47                        starbucks-cary-10                      Starbucks
# 19                      pattis-cafe-raleigh                   Patti's Cafe
# 68                       circle-k-raleigh-4                       Circle K
# 13                      mcdonalds-raleigh-6                     McDonald's
# 28                          crema-raleigh-2                          Crema
# 35                     starbucks-raleigh-43                      Starbucks
# 41                 port-city-java-raleigh-6                 Port City Java
# 23                  kale-me-crazy-raleigh-2                  Kale Me Crazy
# 10                hillsborough-mart-raleigh              Hillsborough Mart
# 73  western-dragon-teas-and-tisanes-raleigh  Western Dragon Teas & Tisanes
# 64                 holy-moly-cannoli-durham              Holy Moly Cannoli
# 85                        starbucks-cary-14                      Starbucks
#
#     rating price  review_count  \
# 88     1.0   $$$             1
# 84     1.0    $$             2
# 82     1.0   NaN             1
# 71     1.0   NaN            10
# 45     1.5     $            34
# 87     1.5     $             7
# 51     1.5     $            13
# 40     1.5     $            30
# 52     1.5     $            13
# 55     1.5   NaN            12
# 56     1.5     $            12
# 46     1.5     $            25
# 59     1.5     $            15
# 83     1.5     $            26
# 80     1.5     $             2
# 79     1.5     $            33
# 78     1.5     $             7
# 75     1.5   NaN             3
# 74     2.0     $            29
# 49     2.0     $            13
# 39     2.0     $            24
# 32     2.0     $            30
# 31     2.0     $            22
# 76     2.0     $             9
# 57     2.0    $$            10
# 48     2.0     $            16
# 24     2.0    $$            37
# 70     2.5   NaN             2
# 15     2.5     $            26
# 16     2.5    $$            31
# ..     ...   ...           ...
# 3      3.5    $$            27
# 4      3.5    $$            28
# 6      3.5     $            17
# 9      3.5   NaN            18
# 72     3.5   NaN             2
# 18     3.5     $            10
# 44     3.5   NaN             3
# 53     3.5    $$            15
# 26     3.5    $$             6
# 61     3.5     $             3
# 58     3.5    $$             2
# 66     4.0   NaN             1
# 1      4.0    $$            16
# 2      4.0    $$            14
# 81     4.0   NaN             4
# 8      4.0   NaN            11
# 20     4.0     $             6
# 69     4.0     $             1
# 47     4.0     $            20
# 19     4.0     $             7
# 68     4.0   NaN             1
# 13     4.5     $             6
# 28     4.5   NaN             4
# 35     4.5     $             3
# 41     4.5     $             2
# 23     4.5   NaN             3
# 10     5.0     $             5
# 73     5.0   NaN             2
# 64     5.0   NaN             7
# 85     5.0   NaN             1
#
#                                           coordinates
# 88     {'latitude': 35.86067, 'longitude': -78.60021}
# 84     {'latitude': 35.86614, 'longitude': -78.56797}
# 82     {'latitude': 35.800831, 'longitude': -78.5601}
# 71  {'latitude': 35.8554331326843, 'longitude': -7...
# 45  {'latitude': 35.7852416, 'longitude': -78.6879...
# 87  {'latitude': 35.7247354, 'longitude': -78.6495...
# 51  {'latitude': 35.7905898785025, 'longitude': -7...
# 40  {'latitude': 35.7357958664346, 'longitude': -7...
# 52  {'latitude': 35.8799164272446, 'longitude': -7...
# 55  {'latitude': 35.8417176029815, 'longitude': -7...
# 56  {'latitude': 35.8701926475536, 'longitude': -7...
# 46  {'latitude': 35.7900417, 'longitude': -78.7407...
# 59  {'latitude': 35.7724070648646, 'longitude': -7...
# 83  {'latitude': 35.7764412369757, 'longitude': -7...
# 80  {'latitude': 35.7885869, 'longitude': -78.6733...
# 79  {'latitude': 35.7590502533454, 'longitude': -7...
# 78  {'latitude': 35.8205101, 'longitude': -78.5912...
# 75  {'latitude': 35.8386157, 'longitude': -78.6751...
# 74  {'latitude': 35.8297788580362, 'longitude': -7...
# 49  {'latitude': 35.9002554552376, 'longitude': -7...
# 39    {'latitude': 35.90633, 'longitude': -78.601383}
# 32  {'latitude': 35.863362088857, 'longitude': -78...
# 31  {'latitude': 35.8191246456017, 'longitude': -7...
# 76  {'latitude': 35.8991828840439, 'longitude': -7...
# 57  {'latitude': 35.8307228088379, 'longitude': -7...
# 48    {'latitude': 35.887576, 'longitude': -78.74405}
# 24   {'latitude': 35.773846, 'longitude': -78.639637}
# 70  {'latitude': 35.7859827, 'longitude': -78.6671...
# 15   {'latitude': 35.836028, 'longitude': -78.675723}
# 16   {'latitude': 35.855675, 'longitude': -78.580519}
# ..                                                ...
# 3     {'latitude': 35.904845, 'longitude': -78.60199}
# 4   {'latitude': 35.887828, 'longitude': -78.67873...
# 6      {'latitude': 35.77787, 'longitude': -78.63456}
# 9   {'latitude': 35.9069964943874, 'longitude': -7...
# 72   {'latitude': 35.77945, 'longitude': -78.6456805}
# 18  {'latitude': 35.7991136276413, 'longitude': -7...
# 44   {'latitude': 35.837276, 'longitude': -78.642334}
# 53   {'latitude': 35.771534, 'longitude': -78.762499}
# 26  {'latitude': 35.7439383895825, 'longitude': -7...
# 61  {'latitude': 35.7678038, 'longitude': -78.7407...
# 58     {'latitude': 35.84836, 'longitude': -78.60065}
# 66  {'latitude': 35.7875118, 'longitude': -78.6696...
# 1    {'latitude': 35.824885, 'longitude': -78.707222}
# 2     {'latitude': 35.866613, 'longitude': -78.57499}
# 81    {'latitude': 35.74687, 'longitude': -78.743381}
# 8    {'latitude': 35.862906, 'longitude': -78.599158}
# 20  {'latitude': 35.7940979003906, 'longitude': -7...
# 69   {'latitude': 35.86684, 'longitude': -78.5417499}
# 47     {'latitude': 35.74615, 'longitude': -78.74189}
# 19    {'latitude': 35.89582, 'longitude': -78.659103}
# 68     {'latitude': 35.79847, 'longitude': -78.55692}
# 13  {'latitude': 35.7237350457159, 'longitude': -7...
# 28      {'latitude': 35.7744, 'longitude': -78.63936}
# 35  {'latitude': 35.78347336, 'longitude': -78.670...
# 41     {'latitude': 35.79738, 'longitude': -78.70438}
# 23  {'latitude': 35.7910333, 'longitude': -78.6609...
# 10   {'latitude': 35.7831199, 'longitude': -78.65621}
# 73     {'latitude': 35.77945, 'longitude': -78.64568}
# 64     {'latitude': 35.93373, 'longitude': -79.01584}
# 85   {'latitude': 35.775164, 'longitude': -78.764947}
#
# [89 rows x 6 columns]

# %%
#Plot ratings (try 4 different plots and then select)
#Bar graph
x_axis = np.arange(len(top_raleighC))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(30, 5))
plt.bar(x_axis, top_raleighC['rating'], color='brown', alpha=0.5, align='center')
plt.xticks(tick_locations, top_raleighC['name'], rotation='vertical')
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(top_raleighC['rating']))
plt.tight_layout()
plt.show()

# %%
multi_plot = top_raleighC.plot(kind="bar", figsize=(50,5))
multi_plot.set_xticklabels(top_raleighC['name'], rotation=45)
plt.tight_layout()
plt.show()
